# %% [markdown]
# # データの観察と理解
#
# `population.csv`ファイルと`covid-19_cases.csv`ファイルにはそれぞれ以下のように都道府県ごとの人口（2017年度の数値）と都道府県ごとのcovid-19の感染者数（2021年10月16日時点）のデータが含まれています。
#
# ```Python
# ## population.csvファイル
# Prefecture, Population
# 北海道, 5320000
# 青森県, 1278000
# 岩手県, 1255000
# ...
#
# ## covid-19_cases.csvファイル
# Prefecture, Cases
# 北海道, 60570
# 青森県, 5870
# 岩手県, 3486
# ...
# ```
#
# これらのデータを元に、各都道府県ごとの10万人あたりの感染者数を求め、それらの記述統計（中心傾向、ばらつき、分布など）を分析する。
#
# データソース
# - [教育用標準データセット 都道府県別データ](https://www.nstac.go.jp/SSDSE/)
# - [NHK 新型コロナウイルス関連データ](https://www3.nhk.or.jp/news/special/coronavirus/data/)

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 0.25.1

# %%
# Colaboratoryでは以下を実行して必要なファイルをダウンロード
# !wget https://raw.githubusercontent.com/UTDataMining/2021S/master/ex3/population.csv

# %%
# Colaboratoryでは以下を実行して必要なファイルをダウンロード
# !wget https://raw.githubusercontent.com/UTDataMining/2021S/master/ex3/covid-19_cases.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import japanize_matplotlib 
import seaborn as sns

# %%
df1 = pd.read_csv('population.csv')
df2 = pd.read_csv('covid-19_cases.csv')
covid = pd.merge(df1, df2, on='Prefecture')
covid.head(10)
# Out:
#   Prefecture  Population  Cases
# 0        北海道     5320000  60570
# 1        青森県     1278000   5870
# 2        岩手県     1255000   3486
# 3        宮城県     2323000  16252
# 4        秋田県      996000   1894
# 5        山形県     1102000   3528
# 6        福島県     1882000   9476
# 7        茨城県     2892000  24351
# 8        栃木県     1957000  15418
# 9        群馬県     1960000  16694

# %%
# 都道府県別10万人あたりの感染者数
covid['Rate'] = covid['Cases']*100000/covid['Population']
covid.sort_values('Rate', ascending=False).head(10)
# Out:
#    Prefecture  Population   Cases         Rate
# 46        沖縄県     1443000   50036  3467.498267
# 12        東京都    13724000  377159  2748.171087
# 26        大阪府     8823000  201684  2285.889153
# 13       神奈川県     9159000  168654  1841.401900
# 11        千葉県     6246000  100154  1603.490234
# 10        埼玉県     7310000  115416  1578.878249
# 39        福岡県     5107000   74292  1454.709223
# 27        兵庫県     5503000   78128  1419.734690
# 22        愛知県     7525000  106326  1412.970100
# 25        京都府     2599000   35788  1376.991150

# %%
# 棒グラフ
covid.plot.bar(x='Prefecture', y='Rate', figsize=(10,5));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-49f5804914fd> in <module>
#       1 # 棒グラフ
# ----> 2 covid.plot.bar(x='Prefecture', y='Rate', figsize=(10,5));
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#     946             >>> ax = df.plot.bar(x='lifespan', rot=0)
#     947         """
# --> 948         return self(kind="bar", x=x, y=y, **kwargs)
#     949
#     950     def barh(self, x=None, y=None, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     402         data = data._convert(datetime=True, timedelta=True)
#     403         numeric_data = data.select_dtypes(
# --> 404             include=[np.number, "datetime", "datetimetz", "timedelta"]
#     405         )
#     406
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# -> 3427         include_these = Series(not bool(include), index=self.columns)
#    3428         exclude_these = Series(not bool(exclude), index=self.columns)
#    3429
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# ヒストグラム
covid['Rate'].hist(bins=15);

# %%
# 記述統計
covid['Rate'].describe()
# Out:
# count      47.000000
# mean      882.637753
# std       661.987283
# min       190.160643
# 25%       453.511481
# 50%       704.733010
# 75%      1034.182256
# max      3467.498267
# Name: Rate, dtype: float64

# %%
#平均値, 中央値, 偏差, 最小, 最大
print(covid['Rate'].mean(),covid['Rate'].median(), covid['Rate'].std(), covid['Rate'].min(), covid['Rate'].max())
# Out:
# 882.637753497031 704.7330097087379 661.9872832331431 190.1606425702811 3467.4982674982675

# %%
# 箱ヒゲ図
covid['Rate'].plot.box();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-9bc27ac8c0f2> in <module>
#       1 # 箱ヒゲ図
# ----> 2 covid['Rate'].plot.box();
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in box(self, by, **kwargs)
#    1076             >>> ax = df.plot.box()
#    1077         """
# -> 1078         return self(kind="box", by=by, **kwargs)
#    1079
#    1080     def hist(self, by=None, bins=10, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     402         data = data._convert(datetime=True, timedelta=True)
#     403         numeric_data = data.select_dtypes(
# --> 404             include=[np.number, "datetime", "datetimetz", "timedelta"]
#     405         )
#     406
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# -> 3427         include_these = Series(not bool(include), index=self.columns)
#    3428         exclude_these = Series(not bool(exclude), index=self.columns)
#    3429
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# 歪度と尖度
print(covid['Rate'].skew(), covid['Rate'].kurt())
# Out:
# 2.0638509127437024 4.996532919601765

# %%
# 分布のカーネル密度推定
covid['Rate'].plot.kde();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-cc7b4ac2ed11> in <module>
#       1 # 分布のカーネル密度推定
# ----> 2 covid['Rate'].plot.kde();
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1231             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1232         """
# -> 1233         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1234
#    1235     density = kde
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     402         data = data._convert(datetime=True, timedelta=True)
#     403         numeric_data = data.select_dtypes(
# --> 404             include=[np.number, "datetime", "datetimetz", "timedelta"]
#     405         )
#     406
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# -> 3427         include_these = Series(not bool(include), index=self.columns)
#    3428         exclude_these = Series(not bool(exclude), index=self.columns)
#    3429
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# ヒストグラムと分布
covid["Rate"].plot(kind="hist", bins=10)
covid["Rate"].plot(kind="kde", secondary_y=True);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-05ea7f8c5968> in <module>
#       1 # ヒストグラムと分布
# ----> 2 covid["Rate"].plot(kind="hist", bins=10)
#       3 covid["Rate"].plot(kind="kde", secondary_y=True);
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     402         data = data._convert(datetime=True, timedelta=True)
#     403         numeric_data = data.select_dtypes(
# --> 404             include=[np.number, "datetime", "datetimetz", "timedelta"]
#     405         )
#     406
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# -> 3427         include_these = Series(not bool(include), index=self.columns)
#    3428         exclude_these = Series(not bool(exclude), index=self.columns)
#    3429
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# ヒストグラムと分布
sns.distplot(covid['Rate'], bins=10);

# %%
# 相関係数
covid.corr()
# Out:
#             Population     Cases      Rate
# Population    1.000000  0.952960  0.704661
# Cases         0.952960  1.000000  0.754458
# Rate          0.704661  0.754458  1.000000

# %%
# ヒートマップ
sns.heatmap(data=covid.corr());

# %%
# 散布図
covid.plot.scatter(x='Population', y='Rate');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-816ce2c4d9e6> in <module>
#       1 # 散布図
# ----> 2 covid.plot.scatter(x='Population', y='Rate');
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwargs)
#    1442             ...                       colormap='viridis')
#    1443         """
# -> 1444         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1445
#    1446     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     402         data = data._convert(datetime=True, timedelta=True)
#     403         numeric_data = data.select_dtypes(
# --> 404             include=[np.number, "datetime", "datetimetz", "timedelta"]
#     405         )
#     406
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3425         # the "union" of the logic of case 1 and case 2:
#    3426         # we get the included and excluded, and return their logical and
# -> 3427         include_these = Series(not bool(include), index=self.columns)
#    3428         exclude_these = Series(not bool(exclude), index=self.columns)
#    3429
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# 散布図
sns.jointplot(x='Population', y='Rate', data=covid);

# %%
# カーネル密度推定
sns.jointplot(x='Population', y='Rate', data=covid, kind='kde');

# %%
# 散布図
sns.pairplot(data=covid);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e2c7b41783a6> in <module>
#       1 # 散布図
# ----> 2 sns.pairplot(data=covid);
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2119     if kind == "scatter":
#    2120         from .relational import scatterplot  # Avoid circular import
# -> 2121         plotter(scatterplot, **plot_kws)
#    2122     elif kind == "reg":
#    2123         from .regression import regplot  # Avoid circular import
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/seaborn/axisgrid.py in map_offdiag(self, func, **kwargs)
#    1510         """
#    1511
# -> 1512         self.map_lower(func, **kwargs)
#    1513         self.map_upper(func, **kwargs)
#    1514         return self
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/seaborn/axisgrid.py in map_lower(self, func, **kwargs)
#    1440                 color = self.palette[k] if kw_color is None else kw_color
#    1441                 func(data_k[x_var], data_k[y_var], label=label_k,
# -> 1442                      color=color, **kwargs)
#    1443
#    1444             self._clean_axis(ax)
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     850
#     851         plot_data = self.establish_variables(
# --> 852             x, y, hue, size, style, units, data
#     853         )
#     854
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     155                 units=units
#     156             )
# --> 157             plot_data = pd.DataFrame(plot_data)
#     158
#     159         # Option 3:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      80
#      81     # don't force copy because getting jammed in an ndarray anyway
# ---> 82     arrays = _homogenize(arrays, index, dtype)
#      83
#      84     # from BlockManager perspective
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     321                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     322             val = sanitize_array(
# --> 323                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     324             )
#     325
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# ~/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
# 回帰直線
sns.regplot(x='Population', y='Rate', data=covid);

# %%
# 回帰曲線（2次の多項式）
sns.regplot(x='Population', y='Rate', data=covid, order=2);

# %%
# 都道府県の色分け
covid.loc[covid['Rate'] >= covid['Rate'].quantile(.75), 'color']='red'
covid.loc[(covid['Rate'] < covid['Rate'].quantile(.75)) & (covid['Rate'] >= covid['Rate'].quantile(.25)), 'color']='blue'
covid.loc[(covid['Rate'] < covid['Rate'].quantile(.25)), 'color']='green'
covid.head()
# Out:
#   Prefecture  Population  Cases         Rate  color
# 0        北海道     5320000  60570  1138.533835    red
# 1        青森県     1278000   5870   459.311424   blue
# 2        岩手県     1255000   3486   277.768924  green
# 3        宮城県     2323000  16252   699.612570   blue
# 4        秋田県      996000   1894   190.160643  green

# %%
#!pip install japanmap

# %%
# 地図の可視化
import japanmap as jm
pref_colors={p:c for p, c in zip(covid['Prefecture'].values, covid['color'].values)}
image=jm.picture(pref_colors)
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off');
